# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([1.94846429, 1.72993543, 3.60673106, 1.23566496, 3.29547109,
#        2.11201044, 1.71464098, 0.60530971, 4.45477263, 2.71361634,
#        1.77956976, 3.3400973 , 0.89885044, 3.86062965, 3.38039522,
#        2.95512113, 4.25097696, 1.47644454, 2.89740078, 2.34845013,
#        3.86054185, 4.7521259 , 2.41399869, 4.47268516, 3.32043706,
#        0.6490313 , 4.41365628, 3.48662833, 1.96297303, 2.03676133,
#        3.78710562, 2.88187787, 4.28348509, 1.76114233, 4.32312454,
#        1.27931007, 3.07574839, 1.10480561, 4.87298119, 3.50519726,
#        3.70615508, 4.89862636, 2.94687913, 3.27908882, 2.37973796,
#        1.68486739, 1.75099199, 3.58813807, 1.95856345, 3.81903102,
#        3.77392523, 0.34293204, 4.89084813, 2.33660585, 4.04867631,
#        0.19618966, 2.41550838, 2.48945695, 0.30005915, 1.6748353 ,
#        4.82676997, 3.09635861, 1.211092  , 4.4526568 , 2.05069483,
#        3.46924819, 1.27972864, 4.53302717, 0.87189725, 4.7785658 ,
#        0.03181844, 1.45324575, 4.84166817, 4.99942796, 4.53262317,
#        1.32617213, 3.70394888, 2.88430134, 0.94819943, 3.90071073,
#        2.78684573, 2.03359757, 0.69994562, 1.86184645, 4.79188637,
#        2.32926583, 0.66128131, 1.28186219, 0.66175852, 3.05293429,
#        3.65969087, 0.74326876, 1.99027857, 2.88081779, 3.24925432,
#        4.84868564, 0.57540945, 4.38340706, 4.98818189, 3.36380583])

# %%
X # array where each row is an array to
# Out:
# array([[1.94846429],
#        [1.72993543],
#        [3.60673106],
#        [1.23566496],
#        [3.29547109],
#        [2.11201044],
#        [1.71464098],
#        [0.60530971],
#        [4.45477263],
#        [2.71361634],
#        [1.77956976],
#        [3.3400973 ],
#        [0.89885044],
#        [3.86062965],
#        [3.38039522],
#        [2.95512113],
#        [4.25097696],
#        [1.47644454],
#        [2.89740078],
#        [2.34845013],
#        [3.86054185],
#        [4.7521259 ],
#        [2.41399869],
#        [4.47268516],
#        [3.32043706],
#        [0.6490313 ],
#        [4.41365628],
#        [3.48662833],
#        [1.96297303],
#        [2.03676133],
#        [3.78710562],
#        [2.88187787],
#        [4.28348509],
#        [1.76114233],
#        [4.32312454],
#        [1.27931007],
#        [3.07574839],
#        [1.10480561],
#        [4.87298119],
#        [3.50519726],
#        [3.70615508],
#        [4.89862636],
#        [2.94687913],
#        [3.27908882],
#        [2.37973796],
#        [1.68486739],
#        [1.75099199],
#        [3.58813807],
#        [1.95856345],
#        [3.81903102],
#        [3.77392523],
#        [0.34293204],
#        [4.89084813],
#        [2.33660585],
#        [4.04867631],
#        [0.19618966],
#        [2.41550838],
#        [2.48945695],
#        [0.30005915],
#        [1.6748353 ],
#        [4.82676997],
#        [3.09635861],
#        [1.211092  ],
#        [4.4526568 ],
#        [2.05069483],
#        [3.46924819],
#        [1.27972864],
#        [4.53302717],
#        [0.87189725],
#        [4.7785658 ],
#        [0.03181844],
#        [1.45324575],
#        [4.84166817],
#        [4.99942796],
#        [4.53262317],
#        [1.32617213],
#        [3.70394888],
#        [2.88430134],
#        [0.94819943],
#        [3.90071073],
#        [2.78684573],
#        [2.03359757],
#        [0.69994562],
#        [1.86184645],
#        [4.79188637],
#        [2.32926583],
#        [0.66128131],
#        [1.28186219],
#        [0.66175852],
#        [3.05293429],
#        [3.65969087],
#        [0.74326876],
#        [1.99027857],
#        [2.88081779],
#        [3.24925432],
#        [4.84868564],
#        [0.57540945],
#        [4.38340706],
#        [4.98818189],
#        [3.36380583]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(0.9991854858667951)

# %%
b_found
# Out:
# np.float64(2.994545750950045)
